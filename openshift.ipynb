# %%
"""
---Notes on openshift, combined on both laptop and PC

In openshift we have Management side and Execution part

Management part consist off: 
-Integrated Docker Registry
-Source To Image
-Build Configuuration
-Image Stream
-Deployment Configuration

Execute part consists of:
-Replication Controller
-POD (container)
-Persistent Volume Claim
-Persistent Volume
-Services
-Routes

"""
